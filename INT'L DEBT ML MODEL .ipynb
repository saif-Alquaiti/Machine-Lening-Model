# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GDP_DATA = '/Users/olayinkafaniran/Documents/AIDA/AIML COURSEWORK/GDP.csv'
df_gdp = pd.read_csv(GDP_DATA)
df_gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  1.931311e+10  1.972349e+10  2.149392e+10  2.573321e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040428e+10  1.112805e+10  1.194335e+10  1.267652e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2011          2012          2013  \
# ...

# %%
df_gdp = pd.melt(df_gdp, id_vars = ['Country Name','Country Code','Indicator Name','Indicator Code'],
                  var_name = 'Year',
                  value_name = 'GDP',
                  ignore_index = False)
df_gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code  Year           GDP
# 0  NY.GDP.MKTP.CD  1960           NaN
# 1  NY.GDP.MKTP.CD  1960  1.931311e+10
# 2  NY.GDP.MKTP.CD  1960  5.377778e+08
# 3  NY.GDP.MKTP.CD  1960  1.040428e+10
# 4  NY.GDP.MKTP.CD  1960           NaN

# %% [markdown]
# # GINI DATA

# %%
GINI_DATA = '/Users/olayinkafaniran/Documents/AIDA/AIML COURSEWORK/GINI_INDEX.csv'
df_gini = pd.read_csv(GINI_DATA)
df_gini.head()
# Out:
#                         Series Name  Series Code Country Name Country Code  \
# 0  Gini index (World Bank estimate)  SI.POV.GINI  Afghanistan          AFG
# 1  Gini index (World Bank estimate)  SI.POV.GINI      Albania          ALB
# 2  Gini index (World Bank estimate)  SI.POV.GINI      Algeria          DZA
# 3  Gini index (World Bank estimate)  SI.POV.GINI       Angola          AGO
# 4  Gini index (World Bank estimate)  SI.POV.GINI    Argentina          ARG
#
#   1974 [YR1974] 1975 [YR1975] 1976 [YR1976] 1977 [YR1977] 1978 [YR1978]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            ..            ..            ..            ..
# 2            ..            ..            ..            ..            ..
# 3            ..            ..            ..            ..            ..
# 4            ..            ..            ..            ..            ..
#
#   1979 [YR1979]  ... 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# ...

# %%
df_gini = pd.melt(df_gini, id_vars = ['Series Name','Series Code','Country Name','Country Code'],
                  var_name = 'GINI_Year',
                  value_name = 'GINI_Value',
                  ignore_index = False)
df_gini.head()
# Out:
#                         Series Name  Series Code Country Name Country Code  \
# 0  Gini index (World Bank estimate)  SI.POV.GINI  Afghanistan          AFG
# 1  Gini index (World Bank estimate)  SI.POV.GINI      Albania          ALB
# 2  Gini index (World Bank estimate)  SI.POV.GINI      Algeria          DZA
# 3  Gini index (World Bank estimate)  SI.POV.GINI       Angola          AGO
# 4  Gini index (World Bank estimate)  SI.POV.GINI    Argentina          ARG
#
#        GINI_Year GINI_Value
# 0  1974 [YR1974]         ..
# 1  1974 [YR1974]         ..
# 2  1974 [YR1974]         ..
# 3  1974 [YR1974]         ..
# 4  1974 [YR1974]         ..

# %%
df_gini.shape
# Out:
# (9541, 6)

# %%
df_gini.dtypes
# Out:
# Series Name     object
# Series Code     object
# Country Name    object
# Country Code    object
# GINI_Year       object
# GINI_Value      object
# dtype: object

# %%
df_gini['GINI_Value'] = pd.to_numeric(df_gini['GINI_Value'], errors = 'coerce', downcast= 'signed')

# %%
df_gini.dtypes
# Out:
# Series Name      object
# Series Code      object
# Country Name     object
# Country Code     object
# GINI_Year        object
# GINI_Value      float64
# dtype: object

# %%
gini_split = df_gini['GINI_Year'].str.split(' ')
gini_split
# Out:
# 0      [1974, [YR1974]]
# 1      [1974, [YR1974]]
# 2      [1974, [YR1974]]
# 3      [1974, [YR1974]]
# 4      [1974, [YR1974]]
#              ...
# 198    [2020, [YR2020]]
# 199    [2020, [YR2020]]
# 200    [2020, [YR2020]]
# 201    [2020, [YR2020]]
# 202    [2020, [YR2020]]
# Name: GINI_Year, Length: 9541, dtype: object

# %%
df_gini['GINI_Year']= gini_split.str.get(0)
df_gini
# Out:
#                                 Series Name  Series Code Country Name  \
# 0          Gini index (World Bank estimate)  SI.POV.GINI  Afghanistan
# 1          Gini index (World Bank estimate)  SI.POV.GINI      Albania
# 2          Gini index (World Bank estimate)  SI.POV.GINI      Algeria
# 3          Gini index (World Bank estimate)  SI.POV.GINI       Angola
# 4          Gini index (World Bank estimate)  SI.POV.GINI    Argentina
# ..                                      ...          ...          ...
# 198                                     NaN          NaN          NaN
# 199                                     NaN          NaN          NaN
# 200                                     NaN          NaN          NaN
# 201  Data from database: Poverty and Equity          NaN          NaN
# 202                Last Updated: 10/05/2021          NaN          NaN
#
#     Country Code GINI_Year  GINI_Value
# 0            AFG      1974         NaN
# 1            ALB      1974         NaN
# ...

# %%
df_gini.isnull().sum()
# Out:
# Series Name      141
# Series Code      235
# Country Name     235
# Country Code     235
# GINI_Year          0
# GINI_Value      7803
# dtype: int64

# %%
DEBT_DATA = '/Users/olayinkafaniran/Documents/AIDA/AIML COURSEWORK/IDS_CSV/IDS_ALLCountries_Data.csv'
df_debt = pd.read_csv(DEBT_DATA)
df_debt.head()
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan          AFG                 World                   WLD
# 1  Afghanistan          AFG                 World                   WLD
# 2  Afghanistan          AFG                 World                   WLD
# 3  Afghanistan          AFG                 World                   WLD
# 4  Afghanistan          AFG                 World                   WLD
#
#                                          Series Name  Series Code  1970  1971  \
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG   NaN   NaN
# 1  Average grace period on new external debt comm...  DT.GPA.OFFT   NaN   NaN
# 2  Average grace period on new external debt comm...  DT.GPA.PRVT   NaN   NaN
# 3  Average grant element on new external debt com...  DT.GRE.DPPG   NaN   NaN
# 4  Average grant element on new external debt com...  DT.GRE.OFFT   NaN   NaN
#
# ...

# %%
df_debt = pd.melt(df_debt,
             id_vars = ['Country Name', 'Country Code', 'Counterpart-Area Name',
                         'Counterpart-Area Code','Series Name', 'Series Code'],
              var_name = 'Year',
               value_name = 'Value',
                 ignore_index = False)

# %%
df_debt.head()
# Out:
#   Country Name Country Code Counterpart-Area Name Counterpart-Area Code  \
# 0  Afghanistan          AFG                 World                   WLD
# 1  Afghanistan          AFG                 World                   WLD
# 2  Afghanistan          AFG                 World                   WLD
# 3  Afghanistan          AFG                 World                   WLD
# 4  Afghanistan          AFG                 World                   WLD
#
#                                          Series Name  Series Code  Year  Value
# 0  Average grace period on new external debt comm...  DT.GPA.DPPG  1970    NaN
# 1  Average grace period on new external debt comm...  DT.GPA.OFFT  1970    NaN
# 2  Average grace period on new external debt comm...  DT.GPA.PRVT  1970    NaN
# 3  Average grant element on new external debt com...  DT.GRE.DPPG  1970    NaN
# 4  Average grant element on new external debt com...  DT.GRE.OFFT  1970    NaN

# %%
df_debt.shape
# Out:
# (4565951, 8)

# %%
df_gini.shape
# Out:
# (9541, 6)

# %%
df_gdp.shape
# Out:
# (16226, 6)

# %%
df_debt.columns
# Out:
# Index(['Country Name', 'Country Code', 'Counterpart-Area Name',
#        'Counterpart-Area Code', 'Series Name', 'Series Code', 'Year', 'Value'],
#       dtype='object')

# %%
df_debt_total = df_debt.groupby(['Country Name','Year'],as_index = False, dropna = True).sum()

# %%
df_debt_total = df_debt_total.replace()

# %%
df_debt_total.head(100)
# Out:
#    Country Name  Year         Value
# 0   Afghanistan  1970  0.000000e+00
# 1   Afghanistan  1971  0.000000e+00
# 2   Afghanistan  1972  0.000000e+00
# 3   Afghanistan  1973  0.000000e+00
# 4   Afghanistan  1974  0.000000e+00
# ..          ...   ...           ...
# 95      Albania  2006  5.714686e+10
# 96      Albania  2007  6.685732e+10
# 97      Albania  2008  1.011591e+11
# 98      Albania  2009  9.971039e+10
# 99      Albania  2010  1.121744e+11
#
# [100 rows x 3 columns]

# %%
df_debt_total.shape
# Out:
# (8142, 3)

# %%
df_debt_total.value_counts()
# Out:
# Country Name  Year  Value
# Afghanistan   1970  0.000000e+00    1
# Nicaragua     2024  1.503564e+10    1
# Niger         1978  1.178120e+10    1
#               1977  5.565527e+09    1
#               1976  5.261085e+09    1
#                                    ..
# Gambia, The   2024  1.248778e+09    1
#               2023  1.310329e+09    1
#               2022  1.422255e+09    1
#               2021  1.466114e+09    1
# Zimbabwe      2028  5.160289e+09    1
# Length: 8142, dtype: int64

# %%
df_debt_total.describe()
# Out:
#               Value
# count  8.142000e+03
# mean   1.521371e+12
# std    8.389890e+12
# min   -1.643455e+10
# 25%    7.415245e+09
# 50%    5.133888e+10
# 75%    2.569610e+11
# max    1.501738e+14

# %%
list(df_debt_total)
# Out:
# ['Country Name', 'Year', 'Value']

# %%
df_debt_total.reset_index()
# Out:
#       index Country Name  Year         Value
# 0         0  Afghanistan  1970  0.000000e+00
# 1         1  Afghanistan  1971  0.000000e+00
# 2         2  Afghanistan  1972  0.000000e+00
# 3         3  Afghanistan  1973  0.000000e+00
# 4         4  Afghanistan  1974  0.000000e+00
# ...     ...          ...   ...           ...
# 8137   8137     Zimbabwe  2024  6.527163e+09
# 8138   8138     Zimbabwe  2025  6.497502e+09
# 8139   8139     Zimbabwe  2026  6.508380e+09
# 8140   8140     Zimbabwe  2027  5.902107e+09
# 8141   8141     Zimbabwe  2028  5.160289e+09
#
# [8142 rows x 4 columns]

# %%
list(df_debt_total)
# Out:
# ['Country Name', 'Year', 'Value']

# %%
df_debt_total.dtypes
# Out:
# Country Name     object
# Year             object
# Value           float64
# dtype: object

# %%
df = df_gdp.merge(df_debt_total, left_on=['Country Name','Year'],right_on= ['Country Name','Year'], how ='inner')

# %%
df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code  Year  \
# 0  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 1       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 2      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 3    Argentina          ARG  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 4      Armenia          ARM  GDP (current US$)  NY.GDP.MKTP.CD  1970
#
#             GDP         Value
# 0  1.748887e+09  0.000000e+00
# 1           NaN  2.510000e+06
# 2           NaN  0.000000e+00
# 3  3.158421e+10  1.043302e+11
# 4           NaN  0.000000e+00

# %%
df.shape
# Out:
# (6936, 7)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        'Year', 'GDP', 'Value'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# Year                0
# GDP               927
# Value               0
# dtype: int64

# %%
df1 = df.merge(df_gini, left_on=['Country Name','Year'],right_on= ['Country Name','GINI_Year'], how ='outer')

# %%
df1.head()
# Out:
#   Country Name Country Code_x     Indicator Name  Indicator Code  Year  \
# 0  Afghanistan            AFG  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 1       Angola            AGO  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 2      Albania            ALB  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 3    Argentina            ARG  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 4      Armenia            ARM  GDP (current US$)  NY.GDP.MKTP.CD  1970
#
#             GDP         Value Series Name Series Code Country Code_y  \
# 0  1.748887e+09  0.000000e+00         NaN         NaN            NaN
# 1           NaN  2.510000e+06         NaN         NaN            NaN
# 2           NaN  0.000000e+00         NaN         NaN            NaN
# 3  3.158421e+10  1.043302e+11         NaN         NaN            NaN
# 4           NaN  0.000000e+00         NaN         NaN            NaN
#
#   GINI_Year  GINI_Value
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# ...

# %%
df1.shape
# Out:
# (10367, 12)

# %%
list(df1)
# Out:
# ['Country Name',
#  'Country Code_x',
#  'Indicator Name',
#  'Indicator Code',
#  'Year',
#  'GDP',
#  'Value',
#  'Series Name',
#  'Series Code',
#  'Country Code_y',
#  'GINI_Year',
#  'GINI_Value']

# %%
df1['GINI_Value'].isnull().sum()
# Out:
# 8629

# %%
df1.isnull().sum()
# Out:
# Country Name       235
# Country Code_x    3431
# Indicator Name    3431
# Indicator Code    3431
# Year              3431
# GDP               4358
# Value             3431
# Series Name        967
# Series Code       1061
# Country Code_y    1061
# GINI_Year          826
# GINI_Value        8629
# dtype: int64

# %%
df1
# Out:
#       Country Name Country Code_x     Indicator Name  Indicator Code  Year  \
# 0      Afghanistan            AFG  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 1           Angola            AGO  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 2          Albania            ALB  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 3        Argentina            ARG  GDP (current US$)  NY.GDP.MKTP.CD  1970
# 4          Armenia            ARM  GDP (current US$)  NY.GDP.MKTP.CD  1970
# ...            ...            ...                ...             ...   ...
# 10362          NaN            NaN                NaN             NaN   NaN
# 10363          NaN            NaN                NaN             NaN   NaN
# 10364          NaN            NaN                NaN             NaN   NaN
# 10365          NaN            NaN                NaN             NaN   NaN
# 10366          NaN            NaN                NaN             NaN   NaN
#
# ...

# %%
df1.columns
# Out:
# Index(['Country Name', 'Country Code_x', 'Indicator Name', 'Indicator Code',
#        'Year', 'GDP', 'Value', 'Series Name', 'Series Code', 'Country Code_y',
#        'GINI_Year', 'GINI_Value'],
#       dtype='object')

# %%
df1 = df1.drop(['Country Code_x','Indicator Name','Indicator Code',
                 'Series Name','Series Code','Country Code_y'], 
                   axis = 1, inplace = False)

# %%
df1
# Out:
#       Country Name  Year           GDP         Value GINI_Year  GINI_Value
# 0      Afghanistan  1970  1.748887e+09  0.000000e+00       NaN         NaN
# 1           Angola  1970           NaN  2.510000e+06       NaN         NaN
# 2          Albania  1970           NaN  0.000000e+00       NaN         NaN
# 3        Argentina  1970  3.158421e+10  1.043302e+11       NaN         NaN
# 4          Armenia  1970           NaN  0.000000e+00       NaN         NaN
# ...            ...   ...           ...           ...       ...         ...
# 10362          NaN   NaN           NaN           NaN      2020         NaN
# 10363          NaN   NaN           NaN           NaN      2020         NaN
# 10364          NaN   NaN           NaN           NaN      2020         NaN
# 10365          NaN   NaN           NaN           NaN      2020         NaN
# 10366          NaN   NaN           NaN           NaN      2020         NaN
#
# [10367 rows x 6 columns]

# %%
df1['Country Name'].value_counts().max()
# Out:
# 51

# %%
df1 = df1.rename({'GDP':'GDP Value','Value':'Debt Value','GINI_Value':'GINI_Index'}, axis = 1)

# %%
df1
# Out:
#       Country Name  Year     GDP Value    Debt Value GINI_Year  GINI_Index
# 0      Afghanistan  1970  1.748887e+09  0.000000e+00       NaN         NaN
# 1           Angola  1970           NaN  2.510000e+06       NaN         NaN
# 2          Albania  1970           NaN  0.000000e+00       NaN         NaN
# 3        Argentina  1970  3.158421e+10  1.043302e+11       NaN         NaN
# 4          Armenia  1970           NaN  0.000000e+00       NaN         NaN
# ...            ...   ...           ...           ...       ...         ...
# 10362          NaN   NaN           NaN           NaN      2020         NaN
# 10363          NaN   NaN           NaN           NaN      2020         NaN
# 10364          NaN   NaN           NaN           NaN      2020         NaN
# 10365          NaN   NaN           NaN           NaN      2020         NaN
# 10366          NaN   NaN           NaN           NaN      2020         NaN
#
# [10367 rows x 6 columns]

# %%
df1 = df1.dropna(axis = 0, how = 'any')

# %%
df1
# Out:
#      Country Name  Year     GDP Value    Debt Value GINI_Year  GINI_Index
# 1316       Panama  1979  3.704552e+09  4.927563e+10      1979        48.7
# 1363    Argentina  1980  7.696192e+10  4.490386e+11      1980        40.8
# 1433   Madagascar  1980  5.201818e+09  3.547460e+10      1980        46.8
# 1511       Brazil  1981  2.580150e+11  1.611068e+12      1981        57.9
# 1523   Costa Rica  1981  2.623807e+09  5.543045e+10      1981        47.5
# ...           ...   ...           ...           ...       ...         ...
# 6769  El Salvador  2019  2.689666e+10  3.248889e+11      2019        38.8
# 6778     Thailand  2019  5.442640e+11  3.022208e+12      2019        34.9
# 6784       Turkey  2019  7.610040e+11  5.540157e+12      2019        41.9
# 6787      Ukraine  2019  1.538830e+11  1.604709e+12      2019        26.6
# 6799     Zimbabwe  2019  1.928429e+10  1.485757e+11      2019        50.3
#
# [1054 rows x 6 columns]

# %%
df1.dtypes
# Out:
# Country Name     object
# Year             object
# GDP Value       float64
# Debt Value      float64
# GINI_Year        object
# GINI_Index      float64
# dtype: object

# %%
df1.dtypes
# Out:
# Country Name     object
# Year             object
# GDP Value       float64
# Debt Value      float64
# GINI_Year        object
# GINI_Index      float64
# dtype: object

# %%
df1.shape
# Out:
# (1054, 6)

# %%
df1['GINI_Year'].unique()
# Out:
# array(['1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'], dtype=object)

# %%
df1['Year'].unique()
# Out:
# array(['1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'], dtype=object)

# %%
df1['Year'] == df1['GINI_Year']
# Out:
# 1316    True
# 1363    True
# 1433    True
# 1511    True
# 1523    True
#         ...
# 6769    True
# 6778    True
# 6784    True
# 6787    True
# 6799    True
# Length: 1054, dtype: bool

# %%
df1.describe(include = 'all')
# Out:
#        Country Name  Year     GDP Value    Debt Value GINI_Year   GINI_Index
# count          1054  1054  1.054000e+03  1.054000e+03      1054  1054.000000
# unique          116    41           NaN           NaN        41          NaN
# top          Brazil  2012           NaN           NaN      2012          NaN
# freq             35    48           NaN           NaN        48          NaN
# mean            NaN   NaN  2.267722e+11  1.116829e+12       NaN    42.192600
# std             NaN   NaN  8.390506e+11  2.652596e+12       NaN     9.055017
# min             NaN   NaN  1.966525e+08  8.270923e+08       NaN    24.000000
# 25%             NaN   NaN  7.644530e+09  7.672532e+10       NaN    35.400000
# 50%             NaN   NaN  2.686420e+10  2.224279e+11       NaN    41.400000
# 75%             NaN   NaN  1.479175e+11  1.036746e+12       NaN    48.900000
# max             NaN   NaN  1.123330e+13  3.053689e+13       NaN    65.800000

# %%
df1['GINI_Index'].value_counts(sort = True, dropna = True)
# Out:
# 35.7    10
# 41.3     9
# 36.0     8
# 39.0     8
# 35.4     8
#         ..
# 64.7     1
# 61.4     1
# 30.4     1
# 63.3     1
# 26.1     1
# Name: GINI_Index, Length: 338, dtype: int64

# %%
df1.head()
# Out:
#      Country Name  Year     GDP Value    Debt Value GINI_Year  GINI_Index
# 1316       Panama  1979  3.704552e+09  4.927563e+10      1979        48.7
# 1363    Argentina  1980  7.696192e+10  4.490386e+11      1980        40.8
# 1433   Madagascar  1980  5.201818e+09  3.547460e+10      1980        46.8
# 1511       Brazil  1981  2.580150e+11  1.611068e+12      1981        57.9
# 1523   Costa Rica  1981  2.623807e+09  5.543045e+10      1981        47.5

# %%
df1['GDP Value'] = df1['GDP Value']/1000000000
df1['Debt Value'] = df1['Debt Value']/1000000000
# Out:
# /var/folders/v5/pwzbq71x42bd3tvxrm2fb8qw0000gn/T/ipykernel_16089/500818481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['GDP Value'] = df1['GDP Value']/1000000000
# /var/folders/v5/pwzbq71x42bd3tvxrm2fb8qw0000gn/T/ipykernel_16089/500818481.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Debt Value'] = df1['Debt Value']/1000000000

# %%
df1.head()
# Out:
#      Country Name  Year   GDP Value   Debt Value GINI_Year  GINI_Index
# 1316       Panama  1979    3.704552    49.275627      1979        48.7
# 1363    Argentina  1980   76.961924   449.038551      1980        40.8
# 1433   Madagascar  1980    5.201818    35.474598      1980        46.8
# 1511       Brazil  1981  258.015000  1611.067592      1981        57.9
# 1523   Costa Rica  1981    2.623807    55.430449      1981        47.5

# %%
df1 = df1.drop(['GINI_Year'], 
                   axis = 1, inplace = False)

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
#       index Country Name  Year   GDP Value   Debt Value  GINI_Index
# 0      1316       Panama  1979    3.704552    49.275627        48.7
# 1      1363    Argentina  1980   76.961924   449.038551        40.8
# 2      1433   Madagascar  1980    5.201818    35.474598        46.8
# 3      1511       Brazil  1981  258.015000  1611.067592        57.9
# 4      1523   Costa Rica  1981    2.623807    55.430449        47.5
# ...     ...          ...   ...         ...          ...         ...
# 1049   6769  El Salvador  2019   26.896660   324.888889        38.8
# 1050   6778     Thailand  2019  544.264000  3022.207705        34.9
# 1051   6784       Turkey  2019  761.004000  5540.157311        41.9
# 1052   6787      Ukraine  2019  153.883000  1604.709137        26.6
# 1053   6799     Zimbabwe  2019   19.284290   148.575676        50.3
#
# [1054 rows x 6 columns]

# %%
df1.sort_values(by = ['Country Name', 'Year'],axis = 0, ascending = True, na_position = 'first',inplace = True)

# %%
df1.isnull().sum()
# Out:
# index           0
# Country Name    0
# Year            0
# GDP Value       0
# Debt Value      0
# GINI_Index      0
# dtype: int64

# %%
df1
# Out:
#       index Country Name  Year  GDP Value  Debt Value  GINI_Index
# 158    3538      Albania  1996   3.199641   17.391651        27.0
# 322    4354      Albania  2002   4.348068   33.161728        31.7
# 442    4762      Albania  2005   8.052074   53.756021        30.6
# 562    5170      Albania  2008  12.881354  101.159095        30.0
# 731    5714      Albania  2012  12.319830  117.185954        29.0
# ...     ...          ...   ...        ...         ...         ...
# 687    5574       Zambia  2010  20.265559   85.125089        55.6
# 911    6254       Zambia  2015  21.251217  247.420676        57.1
# 730    5711     Zimbabwe  2011  14.101920  124.835226        43.2
# 996    6527     Zimbabwe  2017  17.584891  153.404347        44.3
# 1053   6799     Zimbabwe  2019  19.284290  148.575676        50.3
#
# [1054 rows x 6 columns]

# %%
df1['Country Name'].unique()
# Out:
# array(['Albania', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Azerbaijan', 'Bangladesh', 'Belarus', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cameroon',
#        'Central African Republic', 'Chad', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.',
#        'El Salvador', 'Eswatini', 'Ethiopia', 'Fiji', 'Gabon',
#        'Gambia, The', 'Georgia', 'Ghana', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'India',
#        'Indonesia', 'Iran, Islamic Rep.', 'Jamaica', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Kosovo', 'Kyrgyz Republic', 'Lao PDR',
#        'Lebanon', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi',
#        'Maldives', 'Mali', 'Mauritania', 'Mauritius', 'Mexico', 'Moldova',
# ...

# %%
filt = ((df1['Country Name'] == 'Algeria')|
        (df1['Country Name'] == 'Albania')|
         (df1['Country Name'] == 'Togo')|
          (df1['Country Name'] == 'Benin')|
        (df1['Country Name'] == 'Cameroon')|
        (df1['Country Name'] == 'Senegal')|
        (df1['Country Name'] == 'Nigeria'))

# %%
df1.loc[filt]
# Out:
#       index Country Name  Year   GDP Value   Debt Value  GINI_Index
# 158    3538      Albania  1996    3.199641    17.391651        27.0
# 322    4354      Albania  2002    4.348068    33.161728        31.7
# 442    4762      Albania  2005    8.052074    53.756021        30.6
# 562    5170      Albania  2008   12.881354   101.159095        30.0
# 731    5714      Albania  2012   12.319830   117.185954        29.0
# 817    5986      Albania  2014   13.228148   126.025710        34.6
# 865    6122      Albania  2015   11.386850   141.576488        32.9
# 912    6258      Albania  2016   11.861200   115.889529        33.7
# 957    6394      Albania  2017   13.019689   140.401680        33.2
# 44     2479      Algeria  1988   59.089067   647.019159        40.2
# 143    3431      Algeria  1995   41.764315   627.083178        35.3
# 701    5607      Algeria  2011  200.013000   595.759654        27.6
# 371    4495        Benin  2003    5.349258    33.836006        38.6
# ...

# %%
df1.groupby('Country Name')

# %%
df1
# Out:
#       index Country Name  Year  GDP Value  Debt Value  GINI_Index
# 158    3538      Albania  1996   3.199641   17.391651        27.0
# 322    4354      Albania  2002   4.348068   33.161728        31.7
# 442    4762      Albania  2005   8.052074   53.756021        30.6
# 562    5170      Albania  2008  12.881354  101.159095        30.0
# 731    5714      Albania  2012  12.319830  117.185954        29.0
# ...     ...          ...   ...        ...         ...         ...
# 687    5574       Zambia  2010  20.265559   85.125089        55.6
# 911    6254       Zambia  2015  21.251217  247.420676        57.1
# 730    5711     Zimbabwe  2011  14.101920  124.835226        43.2
# 996    6527     Zimbabwe  2017  17.584891  153.404347        44.3
# 1053   6799     Zimbabwe  2019  19.284290  148.575676        50.3
#
# [1054 rows x 6 columns]

# %%
df2 = df1.groupby('Year')[['Debt Value','GDP Value']].sum()

# %%
df2.head()
# Out:
#        Debt Value   GDP Value
# Year
# 1979    49.275627    3.704552
# 1980   484.513150   82.163742
# 1981  2339.247156  361.812357
# 1982  1774.256168  271.314000
# 1983  2464.952611  425.528049

# %%
df3 = df1.groupby('Year')[['GINI_Index','Debt Value']].mean()

# %%
df3.head()
# Out:
#       GINI_Index   Debt Value
# Year
# 1979       48.70    49.275627
# 1980       43.80   242.256575
# 1981       51.55   584.811789
# 1982       58.40  1774.256168
# 1983       39.00   821.650870

# %%
df3 = df3.drop('Debt Value', axis = 1)

# %%
df3.head()
# Out:
#       GINI_Index
# Year
# 1979       48.70
# 1980       43.80
# 1981       51.55
# 1982       58.40
# 1983       39.00

# %%
df3.shape
# Out:
# (41, 1)

# %%
df2.shape
# Out:
# (41, 2)

# %%
df4 = df2.merge(df3, left_on=['Year'],right_on= ['Year'], how ='inner')

# %%
df4 = df4.rename({'GDP Value':'GDP Value (Sum, In Billion $)','Debt Value':'Debt Value (Sum, In Billion $)',
                  'GINI_Index': 'GINI Index, Average (As Ratio)'}, axis = 1)

# %%
df4.head()
# Out:
#       Debt Value (Sum, In Billion $)  GDP Value (Sum, In Billion $)  \
# Year
# 1979                       49.275627                       3.704552
# 1980                      484.513150                      82.163742
# 1981                     2339.247156                     361.812357
# 1982                     1774.256168                     271.314000
# 1983                     2464.952611                     425.528049
#
#       GINI Index, Average (As Ratio)
# Year
# 1979                           48.70
# 1980                           43.80
# 1981                           51.55
# 1982                           58.40
# 1983                           39.00

# %%
df4.shape
# Out:
# (41, 3)

# %%
df4.dtypes
# Out:
# Debt Value (Sum, In Billion $)    float64
# GDP Value (Sum, In Billion $)     float64
# GINI Index, Average (As Ratio)    float64
# dtype: object

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 1979 to 2019
# Data columns (total 3 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Debt Value (Sum, In Billion $)  41 non-null     float64
#  1   GDP Value (Sum, In Billion $)   41 non-null     float64
#  2   GINI Index, Average (As Ratio)  41 non-null     float64
# dtypes: float64(3)
# memory usage: 1.3+ KB

# %%
df4.describe()
# Out:
#        Debt Value (Sum, In Billion $)  GDP Value (Sum, In Billion $)  \
# count                       41.000000                      41.000000
# mean                     28710.685983                    5829.706072
# std                      29347.821683                    6943.737844
# min                         49.275627                       3.704552
# 25%                       4493.887151                     648.930892
# 50%                      18950.472750                    2456.025003
# 75%                      41378.545599                    8253.823730
# max                      94011.591802                   22124.511257
#
#        GINI Index, Average (As Ratio)
# count                       41.000000
# mean                        43.718713
# std                          4.251924
# min                         39.000000
# 25%                         40.418919
# 50%                         42.850000
# 75%                         45.385185
# ...

# %%
# df4 = df4.reset_index()

# %%
df4
# Out:
#     Year  Debt Value (Sum, In Billion $)  GDP Value (Sum, In Billion $)  \
# 0   1979                       49.275627                       3.704552
# 1   1980                      484.513150                      82.163742
# 2   1981                     2339.247156                     361.812357
# 3   1982                     1774.256168                     271.314000
# 4   1983                     2464.952611                     425.528049
# 5   1984                     4284.544868                     472.279429
# 6   1985                     2408.850953                     329.385305
# 7   1986                     3276.056886                     610.161691
# 8   1987                     6881.105597                     934.187119
# 9   1988                     3687.093228                     474.950595
# 10  1989                     4493.887151                     648.930892
# 11  1990                     7436.435046                    1222.412666
# ...

# %%
# df4.to_csv('grp43_file.csv', index = False)

# %%
data = pd.read_csv('/Users/olayinkafaniran/Downloads/grp43_file.csv')

# %%
data.head()
# Out:
#    Year  Debt Value (Sum, In Billion $)  GDP Value (Sum, In Billion $)  \
# 0  1979                       49.275627                       3.704552
# 1  1980                      484.513150                      82.163742
# 2  1981                     2339.247156                     361.812357
# 3  1982                     1774.256168                     271.314000
# 4  1983                     2464.952611                     425.528049
#
#    GINI Index, Average (As Ratio)
# 0                           48.70
# 1                           43.80
# 2                           51.55
# 3                           58.40
# 4                           39.00
